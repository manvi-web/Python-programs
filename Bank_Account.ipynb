# %%
class Account:
    def __init__(self,balance,Account_no):
        self.balance=balance
        self.Account_no=Account_no
    def debit(self,ammount):
        self.balance-=ammount
        print(self.balance)
    def credit(self,ammount):
        self.balance+=ammount
        print(self.balance)
    def total(self):
        print(self.balance)
s1=Account(3000,1234)
s1.credit(2000)
s1.debit(1000)
s1.total()
# Out:
# 5000
# 4000
# 4000
