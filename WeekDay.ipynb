# %%
day =int(input("Enter day number"))
if(day==0):
    print("Mon")
elif(day==1):
    print("Tuesday")
elif(day==2):
    print("wed")
elif(day==3):
    print("Friday")
else:
    print("Sunday")
# Out:
# Enter day number 4
# Sunday
